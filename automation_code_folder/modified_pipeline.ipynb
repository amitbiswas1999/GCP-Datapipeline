# %%
import os
PATH=os.path.join(os.getcwd(),'master-shell-352711-035a6f0dc8c6.json')
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=PATH
import slack 
import os
import random  
import gspread
import pandas as pd
cred_file = "master-shell-352711-9f095697259f.json"

# %%
from google.cloud import storage
from google.cloud.storage import Blob

import io
import os 
from google.cloud.storage import Blob
import google.auth
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2 import service_account
from googleapiclient.http import MediaIoBaseDownload
import gspread
import pandas as pd
cred_file = "master-shell-352711-9f095697259f.json"

# %%
# SLACK_TOKEN='xoxb-4512875784421-4501378594695-cH5oM24A9d2jGSWLaZvcvyWq'
# client=slack.WebClient(SLACK_TOKEN)
# channel_name='nsjnaj_winssssss_ahbjh'
# t=random.randint(0,9999)
# channel_name=channel_name.lower()
# create_channel=channel_name+'_'+str(t)
# response = client.conversations_create(
#     # The name of the conversation
#     name=channel_name,
#     decription='hubdbw ndniewndiu jnidniwnd nkjndjwnd'
# )
# channel_id = response["channel"]["id"]

# %% [markdown]
# #  Slack channel creation

# %%
import schedule
import time


# def content_details():
#     gc = gspread.service_account(cred_file)
#     database = gc.open("Content_details")
#     wks = database.worksheet("Sheet1")
#     data = pd.DataFrame(wks.get_all_records())
#     content_name=data['Content_name'].to_list()
#     return content_name

def channel_list():
    SLACK_TOKEN='xoxb-4512875784421-4501378594695-cH5oM24A9d2jGSWLaZvcvyWq'
    client=slack.WebClient(SLACK_TOKEN)
    result = client.conversations_list()
    channels_list=[]
    for items in result["channels"]:
        channels_list.append(items['name'])
        
    return channels_list




def create_slack_channel(channel_name):  
    SLACK_TOKEN='xoxb-4512875784421-4501378594695-cH5oM24A9d2jGSWLaZvcvyWq'
    client=slack.WebClient(SLACK_TOKEN)
    t=random.randint(0,9999)
    channel_name=channel_name.lower()
    create_channel=channel_name+'_'+str(t)
    response = client.conversations_create(
        # The name of the conversation
        name=create_channel
    )
    channel_id = response["channel"]["id"]
#     response = client.conversations_archive(channel=channel_id)
    return channel_id


def channel_mod(string_list):
    mod_list=[]
    for items in string_list:
        items=items.split('_')
        items='_'.join(items[:-1])
        mod_list.append(items)
        
    return mod_list

# %% [markdown]
# # Create parenet folder and subfolder form spreadsheets

# %%
from googleapiclient import discovery
from apiclient.http import MediaFileUpload
# creds, _ = google.auth.default()
# drive_service = discovery.build('drive', 'v3', credentials=creds)

def uploadDOCfile(filename,folderid):
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    filename=filename+'.docx'
    drive_service = discovery.build('drive', 'v3', credentials=creds)

    file_metadata = {'name': filename,
                     "parents": [folderid]
                     }
    media = MediaFileUpload(filename,
                            mimetype='application/vnd.openxmlformats-officedocument.wordprocessingml.document')
    file = drive_service.files().create(body=file_metadata,
                                        media_body=media,
                                        fields='id').execute()
    print('File ID: %s' % file.get('id'))
  
# #sample to use it:
# filename = 'demo.docx'
# filepath = 'demo.docx'
# # mimetype = 'application/vnd.openxmlformats-officedocument.wordprocessingml.document'
# folderid = "1Akxg3U52cmePwza94IhFl_6uWVEhYRcR" #ex:'1tQ63546ñlkmulSaZtz5yeU5YTSFMRRnJz'
# uploadDOCfile(filename, folderid)

# %%
from __future__ import print_function
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']


#chanel_name=content_name[0]
#     chanel_name=chanel_name.lower()
#     print(chanel_name)chanel_name=content_name[0]
#     chanel_name=chanel_name.lower()
#     print(chanel_name)





def getFileList(N):

    creds, _ = google.auth.default()

    # Connect to the API service
    service = build('drive', 'v3', credentials=creds)

    
    resource = service.files()
    result = resource.list(pageSize=N, fields="files(id, name)").execute()
    file_list = result.get('files')
    all_folder_list=[]
    for file in file_list:
        all_folder_list.append(file['name'])
    

    return all_folder_list


def creators_name(df):
    lst=[]
    channel_auth=df['create_folder'].values[0]
    if channel_auth=='yes':
        if df['graphics_designer'].values[0] != '':
            lst.append(df['graphics_designer'].values[0])

        if df['story_writer'].values[0] != '':
            lst.append(df['story_writer'].values[0])

    return lst



def spreadsheet_record(spreadsheetname):
    gc = gspread.service_account(cred_file)
    database = gc.open(spreadsheetname)
    wks = database.worksheet("Sheet1")
    data = pd.DataFrame(wks.get_all_records())
    creatores_name=data['Name'].to_list()
    return creatores_name



def content_details():
    gc = gspread.service_account(cred_file)
    database = gc.open("Content_details")
    wks = database.worksheet("Sheet1")
    data = pd.DataFrame(wks.get_all_records())
    st=data.tail(1)
    return st
    


def create_parent_folder(foldername):
    
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

        try:
            
            # create drive api client
            service = build('drive', 'v3', credentials=creds)
            file_metadata = {
                'name': foldername,
                'mimeType': 'application/vnd.google-apps.folder'
            }

            # pylint: disable=maybe-no-member
            file = service.files().create(body=file_metadata, fields='id'
                                          ).execute()
            print(F'Folder ID: "{file.get("id")}".')
            return file.get('id')

            
            
        except HttpError as error:
            # TODO(developer) - Handle errors from drive API.
            print(f'An error occurred: {error}')

                  
        
def createRemoteFolder(folderName, parentID,filename):
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
            
    for items in folderName:
        
        drive_service = build('drive', 'v3', credentials=creds)

        # Create a folder on Drive, returns the newely created folders ID
        body = {
            'name': items,
            'mimeType': 'application/vnd.google-apps.folder',
            'parents':[parentID]

        }
    #     if parentID:
    #         body['parents'] = [{'id': parentID}]
        root_folder = drive_service.files().create(body = body).execute()
        print(F'SUB_Folder ID: "{root_folder.get("id")}".')
        child_folder_id=root_folder.get("id")
        uploadDOCfile(filename,child_folder_id)
#     return root_folder['id']

# %%
# def creators_name(df):
#     lst=[]
#     channel_auth=df['create_folder'].values[0]
#     if channel_auth=='yes':
#         if df['graphics_designer'].values[0] != '':
#             lst.append(df['graphics_designer'].values[0])

#         if df['story_writer'].values[0] != '':
#             lst.append(df['story_writer'].values[0])

#     return lst

# %%
from docx import Document
from docx.shared import Inches

def create_doc(paragraph,content_name):
    
    document = Document()

    document.add_heading(content_name, 0)
    document.add_paragraph(paragraph)
     
    doc_name=content_name+'.docx'
    document.save(doc_name)
    
    
    
# df=content_details()   
# create_doc(df['content description'].values[0],df['Content_name'].values[0])

# %%
import schedule
import time
import pickle


    

def main_py():
    df=content_details()
    
    with open("drive_folder_list", "rb") as fp:
        folder_list = pickle.load(fp)
    
    
    channel_auth=df['create_slack_channel'].values[0] 
    folder_auth=df['create_folder'].values[0]
    
    channels_item=channel_list()
    updated_list=channel_mod(channels_item)
    
    
    if channel_auth=='yes':
        if df['Content_name'].values[0] not in updated_list:
            create_slack_channel( df['Content_name'].values[0])
            print("channel_created_successfuly")
        else:
            print('channel_exist')
            
    else:
        print('not created yet')
        
    if folder_auth=='yes': 
        
        if df['Content_name'].values[0] in folder_list:
            print('folder_exist')
            print('\n')
        else:
            parentfolderID=create_parent_folder(df['Content_name'].values[0])
            creator_name=creators_name(df)
            
            create_doc(df['content description'].values[0],df['Content_name'].values[0])
#             filename=df['Content_name'].values[0]
            createRemoteFolder(creator_name, parentID=parentfolderID, filename=df['Content_name'].values[0])
            
            print('folder created')
            f=open("drive_folder_list", 'wb')
            pickle.dump(df['Content_name'].values[0],f)
            f.close()
            
            
    else:
        print('folder_not_created_yet')
        
        
    
schedule.every(1).seconds.do(main_py)
  
while True:
    schedule.run_pending()
    time.sleep(1)


# main_py()
# Out:
# channel_created_successfuly
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=563165058799-0ngsr5ll27hpp8ab6cbdhn7bifikk79t.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A45105%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=ajhsdXxZn102zVpplmNhCY3dqp7iZf&access_type=offline
# Folder ID: "1AaJ_jtVK1eg8J0OqAlYyZfXc8YK-JUY3".
# SUB_Folder ID: "1jGKCkzKL5MgCru4N23OMmt03y6QV39wC".
# File ID: 1mhz8m7-jHu3ccIdr-rshQnKc8e4BeTHu
# SUB_Folder ID: "1J5bhUq_HErtdl2zCcHjLmr93xAq77yFh".
# File ID: 1PXu7xvGTkspNwmGbOtlGbkq_R01DkDGw
# folder created
# channel_exist
# folder_exist
#
#
# channel_exist
# folder_exist
#
#
# channel_exist
# folder_exist
#
#
# channel_exist
# folder_exist
#
#
# channel_exist
# folder_exist

# %%
# !pip install python-docx

# %% [markdown]
# #  Store folder items

# %%
def getFileList(N):
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.

    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    # Connect to the API service
    service = build('drive', 'v3', credentials=creds)


    resource = service.files()
    result = resource.list(pageSize=N, fields="files(id, name)").execute()
    file_list = result.get('files')
    all_folder_list=[]
    for file in file_list:
        all_folder_list.append(file['name'])


    return all_folder_list


list_item=getFileList(50)
with open("drive_folder_list", "wb") as fp:
    pickle.dump(list_item, fp)

# %% [markdown]
# #   Upload file from gdrive to GCP bucket

# %%
def subfolder_name():
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())


    drive = build('drive', 'v3', credentials=creds)

    files = []
    subfolder=[]
    page_token = None
    file_to_download = None


    folderId = drive.files().list(q = "mimeType = 'application/vnd.google-apps.folder' and name = 'fifa_wins'", pageSize=10, fields="nextPageToken, files(id, name)").execute()
    folderIdResult = folderId.get('files', [])

    id = folderIdResult[0].get('id')
    results = drive.files().list(q = "'" + id + "' in parents", pageSize=10, fields="nextPageToken, files(id, name)").execute()

    items = results.get('files', [])  

    if not items:
        print('No files found.')
        return
    print('Files:')
    for item in items:
        print(u'{0} ({1})'.format(item['name'], item['id']))
        subfolder.append(item['name'])
        
        
    return subfolder

# %%
sub_folder=subfolder_name()
sub_folder
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=563165058799-0ngsr5ll27hpp8ab6cbdhn7bifikk79t.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A59567%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=0oosZc8NDfQjyYXlqY55tlbcOJlMtt&access_type=offline
# Files:
# suman (1dIQJfRUqErqrId5MHDe6NS3Zs2SliOjH)
# sumit (1XqAUyT18kv4_jUfIQAlbdev0GcH-r_Vc)
# amit (1wx1EyQYf_YexPa-5VfV6HDg-_4yY7-cc)
# ['suman', 'sumit', 'amit']

# %%
from __future__ import print_function
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']



def get_blobs():
    client = storage.Client() 
    bucket_name = client.get_bucket("fifaworldcup2022")
    objects_in_bucket = client.list_blobs(bucket_name, fields='items(name)')
    object_names = []
    for object in objects_in_bucket:
        object_names.append(object.name)
    return object_names




def main_py(items):
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    try:
        drive = build('drive', 'v3', credentials=creds)
        
        files = []
        page_token = None
        file_to_download = None
        objects_list = get_blobs()
        
       
        
        while True:
            
            mimtype="mimeType = 'application/vnd.google-apps.folder' and name = {}".format("'"+items+"'")
            folderId = drive.files().list(q = mimtype, pageSize=10, fields="nextPageToken, files(id, name)").execute()
            folderIdResult = folderId.get('files', [])

            id = folderIdResult[0].get('id')
            results = drive.files().list(q = "'" + id + "' in parents", pageSize=10, fields="nextPageToken, files(id, name)").execute()

            items = results.get('files', [])  

            if not items:
                print('No files found.')
                return
            print('Files:')
            for item in items:
                print(u'{0} ({1})'.format(item['name'], item['id']))
                file_id = item.get("id")
                file_name = item.get("name")
                if file_name not in objects_list:
                    request = drive.files().get_media(fileId=file_id)
                    file_download_buffer = io.BytesIO()
                    downloader = MediaIoBaseDownload(file_download_buffer, request)
                    done = False
                    while done is False:
                        status, done = downloader.next_chunk()
                        print(F'Download {int(status.progress() * 100)}.')

                    upload_to_drive(file_download_buffer,file_name)

            files.extend(folderId.get('files', []))
            page_token = folderId.get('nextPageToken', None)


            if page_token is None:
                break
         
            
            
    except HttpError as error:
        # TODO(developer) - Handle errors from drive API.
        print(f'An error occurred: {error}')

        
    
# def upload_to_drive(file, file_name):
#     client = storage.Client()
#     bucket_name = client.get_bucket("practise_bucket3456")
# #     blob = Blob(file_name, bucket_name)
#     blob = bucket_name.blob("amit/"+file_name)
#     #blob.upload_from_filename(source_file_name)
#     blob.upload_from_filename(file, rewind=True)
    
    
    
        
def upload_to_drive(file, file_name):
    client = storage.Client()
    bucket_name = client.get_bucket("fifaworldcup2022")
    blob = Blob(file_name, bucket_name)
    blob.upload_from_file(file, rewind=True)
    
    
    
    

def main():
    sub_folder=subfolder_name()
    for items in sub_folder:
        main_py(items)
        
        
main()
# Out:
# Files:
# suman (1dIQJfRUqErqrId5MHDe6NS3Zs2SliOjH)
# sumit (1XqAUyT18kv4_jUfIQAlbdev0GcH-r_Vc)
# amit (1wx1EyQYf_YexPa-5VfV6HDg-_4yY7-cc)
# No files found.
# No files found.
# No files found.

# %%
# import the required libraries
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request




SCOPES = ['https://www.googleapis.com/auth/drive']



def getFileList(N):

    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    # Connect to the API service
    service = build('drive', 'v3', credentials=creds)

    
    resource = service.files()
    result = resource.list(pageSize=N, fields="files(id, name)").execute()
    file_list = result_dict.get('files')
    all_folder_list=[]
# Print every file's name
    for file in file_list:
        all_folder_list.append(file['name'])
    

    return all_folder_list


all_folders=getFileList(50)
all_folders
# Out:
# ['suman',
#  'sumit',
#  'amit',
#  'Cricket_World_CUP',
#  'Content_details',
#  'suman',
#  'sumit',
#  'amit',
#  'FIFA_World_CUP_2022',
#  'New  Attendance Sheet',
#  '16.dec - Pravin Borkar.pdf',
#  'FIFA_World_CUP_2022',
#  '16711735381692710817893164478235 - Pravin Borkar.jpg',
#  '16711733689553745279136661014216 - Pravin Borkar.jpg',
#  'kumar',
#  'contennt',
#  '20221204_093950 - Pravin Borkar.jpg',
#  '14 Dec bord - Pravin Borkar.pdf',
#  'Untitled spreadsheet',
#  'To-do list',
#  'Annual budget',
#  'Annual budget',
#  '13 Dec bord - Pravin Borkar.pdf',
#  'poonam tredars - Pravin Borkar.pdf',
#  'poonam 21 sept bill - Pravin Borkar.pdf',
#  '12 Dec. - Pravin Borkar.pdf',
#  '11 Dec bord - Pravin Borkar.pdf',
#  '10 Dec bord - Pravin Borkar.pdf',
#  '9 Dec bord. - Pravin Borkar.pdf',
#  '9 Dec bord - Pravin Borkar.pdf',
#  'IMG-20221209-WA0042 - Pravin Borkar.jpg',
#  'IMG-20221209-WA0042 - Pravin Borkar.jpg',
#  'IMG-20221209-WA0042 - Pravin Borkar.jpg',
# ...

# %%
def content_details():
    gc = gspread.service_account(cred_file)
    database = gc.open("Content_details")
    wks = database.worksheet("Sheet1")
    data = pd.DataFrame(wks.get_all_records())
    content_name=data['Content_name'].to_list()
    return content_name


df=content_details()

# %%
content_name=content_details()

for item in df:
    if item not in all_folder_list:
        print(item)
# Out:
# Cricket_World_CUP

# %%
content_name=content_details()
content_name[-1]
# Out:
# 'Cricket_World_CUP'

# %%
print('Hi');
